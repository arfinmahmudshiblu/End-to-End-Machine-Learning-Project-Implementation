# %%
  print(Ok)

# %%
mongodb+srv://entarfin:arfin@123@cluster0.y9ggd0v.mongodb.net/?appName=Cluster0
# Out:
# Running cells with 'Python 3.13.9' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Imran/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'
